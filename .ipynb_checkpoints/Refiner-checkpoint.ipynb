# %%
from dotenv import load_dotenv
import os
from typing import List, Dict, Any, Optional, Union

load_dotenv()

import pandas as pd
import numpy as np
from pathlib import Path
from tqdm.notebook import tqdm

# Import from our Classes module
from Classes.model_classes import SQLLineageExtractor
from Classes.helper_classes import SQLLineageResult
from Classes.regexp_extractor import RegexSQLExtractor
from Classes.validation_classes import SQLLineageValidator
from Classes.prompt_refiner import GigaChatSQLLineageAgent


GIGACHAT_CREDENTIALS = os.environ.get("GIGACHAT_CREDENTIALS")

# Get the current working directory
current_dir = Path.cwd()

# Construct the path relative to current directory
file_path = current_dir / 'data' / 'SQL.txt'
file_path_valid = current_dir / 'data' / 'SQL_valid.txt'
file_path_log = current_dir / 'data' / 'logs.json'
wrong_sql_path = current_dir / 'data' / 'worng_sql_parsed.csv'


# Read file with example
with open(file_path, "r", encoding="utf-8") as f:
    SQL = f.read()

# Read file with example (valid for LLM)
with open(file_path_valid, "r", encoding="utf-8") as f:
    SQL_valid = f.read()

PROMPT = """You are a SQL lineage extraction expert. Extract source-to-target lineage from the SQL statement below and return **ONLY** a JSON object with two keys: "target" and "sources".

**SQL Statement:**
{sql_text}

**Extraction Rules:**
1. **Target**: The main object being created/modified (fully qualified name).
2. **Sources**: All base tables/views referenced in the query (fully qualified names, no aliases).
3. Strip all quotes (e.g., "schema"."table" → schema.table).
4. Exclude derived tables, CTEs, system tables.
5. Remove duplicates from sources.
6. Use lowercase for all names.

**Output Format:**
{format_instructions}

**Example:**
SQL: INSERT INTO analytics.sales_summary SELECT p.category, SUM(s.amount) FROM products.raw_data p JOIN sales.transactions s ON p.id = s.product_id;
Output: {{"target": "analytics.sales_summary", "sources": ["products.raw_data", "sales.transactions"]}}

**Your Response (JSON only):**"""
# Out:
# /Users/nikolajabramov/PycharmProjects/llm4s2t/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Create extractor
extractor = SQLLineageExtractor(
    credentials=GIGACHAT_CREDENTIALS,   # or set env var GIGACHAT_API_KEY
    model="GigaChat-Pro",
    verify_ssl_certs=False,
    temperature=0.01
)

# Create agent – it will reuse the extractor and also its own chat model (same config)
agent = GigaChatSQLLineageAgent(
    credentials=GIGACHAT_CREDENTIALS,   # or set env var GIGACHAT_CREDENTIALS
    model="GigaChat-Pro",
    verify_ssl_certs=False,
    temperature=0.01,
    extractor = extractor # refine the prompt for the extractor initialized
)

re_extractor = RegexSQLExtractor()

# %%
print(extractor.prompt.template)
# Out:
# You are a SQL lineage extraction expert. Extract source-to-target lineage from the SQL statement below and return **ONLY** a JSON object with two keys: "target" and "sources".
#
# **SQL Statement:**
# {sql_text}
#
# **Extraction Rules:**
# 1. **Target**: The main object being created/modified (fully qualified name).
# 2. **Sources**: All base tables/views referenced in the query (fully qualified names, no aliases).
# 3. Strip all quotes (e.g., "schema"."table" → schema.table).
# 4. Exclude derived tables, CTEs, system tables.
# 5. Remove duplicates from sources.
# 6. Use lowercase for all names.
#
# **Output Format:**
# {format_instructions}
#
# **Example:**
# SQL: INSERT INTO analytics.sales_summary SELECT p.category, SUM(s.amount) FROM products.raw_data p JOIN sales.transactions s ON p.id = s.product_id;
# Output: {{"target": "analytics.sales_summary", "sources": ["products.raw_data", "sales.transactions"]}}
#
# **Your Response (JSON only):**

# %%
workflow = await agent.acreate_workflow()
compiled_graph = workflow.compile()
compiled_graph

# %%
SQL = pd.read_csv(wrong_sql_path)['ddl'].to_list()[1]

# %%
result = await agent.optimize_prompt(
    sql=SQL,
    expected_result=re_extractor.extract(SQL),
    output_file=file_path_log,   # saves full history
    verbose=True  
)


print("Optimized prompt:\n", result["optimized_prompt"])
print(f"F1 Score: {result['f1_score']:.4f}")
# Out:
# ================================================================================
# STARTING PROMPT OPTIMIZATION (GigaChat Agent - Async)
# ================================================================================
#
# 📝 Initial prompt preview:
# You are a SQL lineage extraction expert. Extract source-to-target lineage from the SQL statement below and return **ONLY** a JSON object with two keys: "target" and "sources".
#
# **SQL Statement:**
# {sql...
#
#
# ################################################################################
# ITERATION 1 / 5
# ################################################################################
#
# ################################################################################
# VALIDATE NODE - Iteration 1/5
# ################################################################################
#
# ============================================================
# VALIDATION
# ============================================================
#
# ========================================
# EXTRACTION ATTEMPT 1/3
# ========================================
# ✓ Extraction successful in 2.25s
#
# ========================================
# EXTRACTION ATTEMPT 1/3
# ========================================
# ✗ Extraction attempt 1 failed: Extractor returned error: Event loop is closed
# Retrying in 2s...
#
# ========================================
# EXTRACTION ATTEMPT 2/3
# ========================================
# ✓ Extraction successful in 4.00s
#
# ============================================================
# REFLECTION - Iteration 1
# ============================================================
# ✓ Improved prompt generated (1374 chars)
#
# ################################################################################
# VALIDATE NODE - Iteration 2/5
# ################################################################################
#
# ============================================================
# VALIDATION
# ============================================================
#
# ========================================
# EXTRACTION ATTEMPT 1/3
# ========================================
# ✗ Extraction attempt 1 failed: Extractor returned error: Event loop is closed
# Retrying in 2s...
#
# ========================================
# EXTRACTION ATTEMPT 2/3
# ========================================
# ✓ Extraction successful in 4.01s
#
# ========================================
# EXTRACTION ATTEMPT 1/3
# ========================================
# ✗ Extraction attempt 1 failed: Extractor returned error: Event loop is closed
# Retrying in 2s...
#
# ========================================
# EXTRACTION ATTEMPT 2/3
# ========================================
# ✓ Extraction successful in 4.18s
#
# 📊 Iteration 1 summary:
#    F1 score   : 1.0000
#    Target      : s_grnplm_vd_t_bvd_db_dmslcl.d_agr_collat_cust
#    Sources     : 2
#    Prompt preview (first 200 chars):
# You are a specialized SQL lineage extraction tool. Your task is to extract **source-to-target lineage** from the given SQL statement and return **EXACTLY AND ONLY** a valid JSON object containing two ...
#
#
# ⏹️ Stopping early at iteration 1 – should_continue = False
#
# 💾 Optimisation history saved to /Users/nikolajabramov/PycharmProjects/llm4s2t/data/logs.json
# Optimized prompt:
#  You are a specialized SQL lineage extraction tool. Your task is to extract **source-to-target lineage** from the given SQL statement and return **EXACTLY AND ONLY** a valid JSON object containing two keys:
#
# 1. `"target"` (a string representing the fully qualified name of the target table/schema, in `schema.table` format)
# 2. `"sources"` (an array of strings listing all directly referenced base tables/views in their fully qualified form, without duplicates, aliases, or derived constructs like CTEs/subqueries)
#
# All names must be converted to lowercase and stripped of quotes. Ensure the result adheres strictly to the following format:
#
# {format_instructions}
#
# **SQL Statement:**
# {sql_text}
#
# **Extraction Guidelines:**
# - **Target Table:** Identify the exact table being inserted into or modified (use its fully qualified name).
# - **Base Sources:** List every directly referenced table/view used within the query (excluding derived tables, CTEs, subqueries, temporary tables, and system tables).
# - **Normalization:** Convert all schema and table names to lowercase, remove surrounding quotes, and ensure proper `schema.table` notation.
# - **Duplicates:** Automatically eliminate duplicate entries from the sources list.
# - **Aliases:** Resolve any column or table aliases back to their original fully qualified names.
#
# Return nothing else except the requested JSON object.
# F1 Score: 1.0000

# %%
REFINED_PROMPT = result["optimized_prompt"]

# %%
# Create extractor
extractor_refine = SQLLineageExtractor(
    credentials=GIGACHAT_CREDENTIALS,   # or set env var GIGACHAT_API_KEY
    model="GigaChat-Pro",
    verify_ssl_certs=False,
    temperature=0.01,
    template=REFINED_PROMPT
)

#Create a validaition Class
validation = SQLLineageValidator()

# %%
df_data = pd.read_csv(wrong_sql_path)

# %%
data_lineage = []
f1_scores = {}
results = []

for index, row in tqdm(df_data.iterrows(), total=len(df_data), desc="🎨 Extracting S2T"):

    target_ = re_extractor.extract(row['ddl'])

    res_ = await validation.run_comprehensive_validation(
        extractor_refine, 
        row['ddl'],
        expected_result=target_)
    results.append(res_)
    try:
        f1_scores[row['table_name']] = res_['metrics']['f1_score']
    except:
        f1_scores[row['table_name']] = 0
        
    data_lineage.append(res_['result'])
# Out:
# 🎨 Extracting S2T:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
np.mean(list(f1_scores.values()))

# %%
df = pd.DataFrame(results)
df.pivot_table(index='status', columns='validation_type', values='message', aggfunc='count').fillna(0.0)
